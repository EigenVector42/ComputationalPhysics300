# %% [markdown]
# <h1> Final Project, Phys 300, Fall 2020
# <h2> Project 7: Random Number Generators
# <h3> Ryan Schauer

# %% [markdown]
# ## 1.1 Introduction
# \
# \
#    Random numbers play an integral part in modern computing. For instance they are necessary for the generation of secure encryption codes used in a multitude of applications related to electronic and computer security: financial transactions, Internet browsing, secure data storage, etc. Random numbers are needed in the gaming industry, for games of chance, for the generation of Lottery numbers, even for usage in video games. Another valuable implementation of random numbers is there usage in research applications, such as Monte Carlo simulations, which use random numbers to simulate natural natural phenomena.
# \
# \
# \
#    In the following sections I will first introduce a little bit of history behind random numbers and the impetus for their generation and then I will discuss two different methods for generating random numbers for modern computing. The first method discussed will be physical random number generators. The second method discussed will the computational methods, primarily Pseudo-Random Number Generators (PRNGs).

# %% [markdown]
# ## 1.2 Ancient Games of Chance
#
#
# <img src=https://collectionapi.metmuseum.org/api/collection/v1/iiif/547955/1093777/main-image width=750 title= "Roman Era Dice: 30 B.C.-A.D. 330">
#
#
# <center>Figure 1. Roman Era Dice Circa 30 B.C.-A.D. 330.
#
# <center>The dice would have been used gaming, with the round box used to prevent dice manipulation.
#
# <center>Currently on view at The Met Fifth Avenue in Gallery 138.
#
# Source:[Metropolitan Museum of Art, New York City](https://www.metmuseum.org/art/collection/search/547955)
#
# <br>
#
#
# Games of chance have been played for thousands of years, as can be illustrated above in Figure 1, which shows six-sided gaming dice from the Roman Empire. These dice, and other objects of random chance, such as coin flips, or blindly pulling a marker from a vessel could be considered to be early tangible examples of random number generators.
#
# It would be impractical to attempt to generate random numbers through methods such as these for modern computational purposes. In the next section we will briefly discuss a common source of random numbers used in the early 20th Century: Random Number Tables and Books.

# %% [markdown]
# ## 1.3 Random Numbers in the first half of the 20th Century
# <br>
#
# ### Random Number Tables
# In 1927, Leonard Tippet published the first table of "random" digits created from a 1925 Census Report. Tables like these were essential for use by statisticians in random sampling experiments (L'Ecuyer 2017). Below is a small sample from a random number table.
# <br><br>
#
# <img src=https://researchbasics.education.uconn.edu/wp-content/uploads/sites/1215/2015/05/RANTBLE-400x300.jpg width=300 title= "Part of a Table of Random Numbers">
#
# <center>Figure 2. Part of a Random Number Table.
# <br><br>
#
# Source: [Random Number Table, Educational Research Basics by Del Siegle, University of Connecticut](https://researchbasics.education.uconn.edu/random-number-table/#)</center>
# <br><br>
#
# ### A Million Random Digits
#
# <br>
# For the next three decades these tables of random numbers would be generated by various means for publication and use. For instance, in 1938, Fisher and Yates published a table created from choosing digits from logarithmic tables (L'Ecuyer 2017). In 1947, the [RAND Corporation](https://www.rand.org/) created a table of one million random decimal digits. These values were created from an electronic device that generated random pulses (L'Ecuyer 2017). The digits were available in the form of computer punch cards, 50 per card, for a total of 20,000 cards. In 1955 a book of these digits was published as well.
#
# The book was reissued in 2001 and can currently be purchased [HERE](https://www.amazon.com/dp/0833030477/ref=cm_sw_em_r_mt_dp_9zzZFbCQWFRNV) from the online retailer [Amazon.com](https://www.amazon.com/).
# <br><br>
#
# <img src=https://images-na.ssl-images-amazon.com/images/I/41XwwSaAtXL._SX384_BO1,204,203,200_.jpg width=300 title= "A Million Random Digits with 100,000 Normal Derivatives">
# <center>Figure 3. RAND Corporations 2001 re-print of their 1957 publication by the same title.
#
# >"It is a book with maximum possible suspense: when you read it sequentially for the first time, after every character, based on what you have read so far, you still have no clue of what comes after!"
# ><br>
# ><b>Pierre L'Ecuyer</b>, from <i>"History of Uniform Random Number Generation"</i>, 2017
#
# <br><br>
#
# The Amazon reviews for the book are also quite funny and well worth the read.
#
# This [LINK](https://www.nist.gov/system/files/documents/2017/04/28/AppenB-HB133-05-Z.pdf) to a PDF on the National Institute of Standards and Technology website contains a Random Number Table with digits extracted from the "Million Random Digits Book."
#
# <br>
#
# Though these methods for acquiring random numbers might be sufficient for small sampling sizes they are insufficient for large scale computations, such as Monte Carlo Simulations. They are also not robust enough for cryptographic applications. To pursue either of these goals, some different approaches were needed.
#
# Next we will dive into some hardware solutions for the generating random numbers. These methods are best suited for cryptographic purposes.

# %% [markdown]
# ## 2.1 Hardware Generation of Random Numbers
# ### ERNIE
# <br>
# There were many different variations on electronic devices for generating random numbers through out the 20th Century.
# <br><br>
# Of note was ERNIE (Electronic Random Number Indicator Equipment) which ran in England from 1957 until 1972. It was used to generate numbers for deteremining winners of the British Savings Bond Lottery. The machine measured electronic noise generated by electrons interacting with neon atoms in a glass. See the video below for a more detailed explanation of the device. ERNIE 4 was brought online in 2004 and uses thermal noise in transistors to generate random bits (L'Ecuyer 204).

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('rOAfbb5D3Dw?start=407', width=560, height=315)
# Out:
#         <iframe
#             width="560"
#             height="315"
#             src="https://www.youtube.com/embed/rOAfbb5D3Dw?start=407"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## 2.2 Modern Physical Random Number Generators
# ### Lava Rand
# <br>
# Random data can be extrated from the environment to generate random data. Data acquired from cameras observing rnadom events is a novel way doing this. One of the most interesting and curious methods of generating random numbers was developed in the early 2000's by the company [LavaRnd](http://www.lavarnd.org/), which used a wall of Lava Lamps observed by a webcam to generate random numbers. The company has since moved away from the Lava Lamps onto more contained sources, such as CCD camera chips (http://www.lavarnd.org/lavarnd.html).
# <br><br>
#
# The company [Cloud Flare](https://blog.cloudflare.com/randomness-101-lavarand-in-production/) continues to maintain a Lava Lamp wall in its San Francisco Office for use in cryptography for its site. Please see the picture below.
# <br><br>
#
# <img src=https://blog.cloudflare.com/content/images/2017/11/lava-lamps.jpg width=750 title= "Cloud Flare Lava Wall">
# <center>Figure 4. Cloud Flare Lava Lamps for Random Number Generation</center>
# <br><br>
#
# The biggest issue with using online services such as these for generating random numbers is latency in the Internet connection, and would not necessarily be useful for time dependent applications. For these reasons, many computer systems employ onboard means for generating random numbers.
# <br><br>
#
#
#
# ### Intel® Digital Random Number Generator (DRNG)
#
# There are many ways to extract random data from modern devices to generate random numbers. The motion of users mouse can be used to generate random numbers, or the frequency of a users key strokes on keyboard.
#
# To solve this problem Intel has implemented a hardware solution for Random Number Generation. The RDRAND and RDSEED architecture instructions are accessible by the local OS in software based pseudorandom number generators (PRNGs). The generation of these numbers is implemented through an entropy source in the processor chipset ([Intel](https://software.intel.com/content/www/us/en/develop/articles/intel-digital-random-number-generator-drng-software-implementation-guide.html)). Below is a graphic from the Intel site illustrating the architecture design of the system.
#
# <br><br>
#
# <img src=https://software.intel.com/content/dam/develop/external/us/en/images/drng-img02-185467.jpg width=500 title= "Intel Digital Random Number Generator design">
# <center>Figure 5. Intel Digital Random Number Generator design architecture</center>
# <br><br>
#
# ### Other Sources of Random Values through Hardware Implementation
#
#
# In an [article](https://www.redhat.com/en/blog/understanding-random-number-generators-and-their-limitations-linux) an RedHat.com, Huzaifa Sidhpurwala gives an excellent description of some the methods that are used a sources for generating random number.
#
# >A hardware RNG could use hard-to-predict values such as wind speed or atmospheric pressure, or exploit intrinsically random (quantum) processes such as photon transmission/reflection through a semi-transparent mirror. In computers we can use the attached hardware to harvest entropy like movement on the mouse pointer, keys typed on the keyboard, and disk and/or network I/O. Such systems are a good source of entropy, however they are slow to yield data (for example the CPU jitter generator). Also they are dependent on external triggers in order to generate random numbers and are often not reliable when large amount of random numbers are required.
#
# As Sidhpurwala notes, these sources are not always reliable for generating large amounts of random numbers. For this we turn to Psudeorandom Number Generators or PRNGs.

# %% [markdown]
# ## 3.1 Psudeorandom Number Generators
#
# ### John von Neumann's Middle Square Method
#
# >Any one who considers arithmetical methods of producing random digits is, of course, in a state of sin. For, as has been pointed out several times, there is no such thing as a random number-there are only methods to produce random numbers, and a strict arithmetic procedure of course is not such a method.
# >
# > <br>
# > <b>John von Neumann</b>, from <i>"Various Techniques Used in Connection With Random Digits"</i>, 1951
#
# John von Neumann proposed the first algorithm for a Random Number Generator in 1947 (von Neumann 1951). The algorithm is called The Middle Squares Method. It is a very simple algorithm. I have demonstrated it below:
#
# <center>
# <h3>Middle Square Method</h3><br><br>
#
# <center>
# <font size="3">
# seed: 5769
# $$\Downarrow$$
# square the seed: $$5769^{2}$$
# $$\Downarrow$$
# Extract the "Middle" number:<br><br>
# 33<u><b>2813</b></u>61
# $$\Downarrow$$
# Add new number to list of Pseudo-Random Numbers:<br><br>
# <b>2813</b><br>
# $$\Downarrow$$
# Square the new number:
# $$2813^{2}$$
# $$\Downarrow$$
# Fill the front with zeros to ensure there are 8-digits to extract a middle number from:<br><br>
# 07<u><b>9129</b></u>69<br>
# $$\Downarrow$$
# Add new number to list of Pseudo-Random Numbers:<br><br>
# <b>9129</b><br>
# $$\Downarrow$$
# Square the new number:
# $$9129^{2}$$
# $$\Downarrow$$
# Rinse and repeat...<br><br>
#
# </font>
# </center>
#
# There are several requirements for the algorithm to work. The n-digit starting value must be even, otherwise a unique "middle digit" might not be obtained. Also, the maximum period length of the sequence will not be longer that $8^{n}$ values ("Middle Square Method", Wikipedia 2020). Though this period limit is rarely reach as the sequence often converges to single value that will then repeat (often that value is zero). Below I have used the Python code provided on the Wikipedia page to demonstrate this issue with the algorithm.

# %%
"""
    Code copied from the The Middle Square Method Wikipedia page:

    https://en.wikipedia.org/wiki/Middle-square_method#Middle_Square_Weyl_Sequence_PRNG

"""

seed_number = int(input("Please enter a four digit number:\n[####] "))
number = seed_number
already_seen = set()
counter = 0

while number not in already_seen:
    counter += 1
    already_seen.add(number)
    """
        The section below is the Middle Square Algorithm.
        1. The input number is squared: number * number
        2. then converted into a string: str(number * number)
        3. The front digits are filled with zeries if necessary to
            bring the string up to 8-digit size: *.zfill(8)
        4. The string is sliced from the 2nd to the 5th indices to
            extract the "middle" number.
        5. Finally the string is converted into a 4-digit number:
            int(str(number * number).zfill(8)[2:6])
        
    """
    number = int(str(number * number).zfill(8)[2:6])  # zfill adds padding of zeroes
    print(f"#{counter}: {number}")

print(f"We began with {seed_number}, and"
      f" have repeated ourselves after {counter} steps"
      f" with {number}.")
# Out:
# Please enter a four digit number:
# [####] 1234
# #1: 5227
# #2: 3215
# #3: 3362
# #4: 3030
# #5: 1809
# #6: 2724
# #7: 4201
# #8: 6484
# #9: 422
# #10: 1780
# #11: 1684
# #12: 8358
# #13: 8561
# #14: 2907
# #15: 4506
# #16: 3040
# #17: 2416
# #18: 8370
# #19: 569
# #20: 3237
# #21: 4781
# #22: 8579
# #23: 5992
# #24: 9040
# #25: 7216
# #26: 706
# #27: 4984
# #28: 8402
# #29: 5936
# #30: 2360
# #31: 5696
# #32: 4444
# #33: 7491
# #34: 1150
# #35: 3225
# #36: 4006
# #37: 480
# #38: 2304
# #39: 3084
# #40: 5110
# #41: 1121
# #42: 2566
# #43: 5843
# #44: 1406
# #45: 9768
# #46: 4138
# #47: 1230
# #48: 5129
# #49: 3066
# #50: 4003
# #51: 240
# #52: 576
# #53: 3317
# #54: 24
# #55: 5
# #56: 0
# #57: 0
# We began with 1234, and have repeated ourselves after 57 steps with 0.

# %% [markdown]
# ## 3.2 Better PRNGs
#
# ### Linear Congruential Generator
#
# Though the Middle Squares Method is beautifully simple and elegant, it is simply not suitable for any random number generation outside of short hand calculations.
#
# A popular algorithm used in the generation of Random Numbers is the [linear congruential generator](https://en.wikipedia.org/wiki/Linear_congruential_generator):
#
# $$X_{n+1}=(aX_{n})\mod{m}$$
#
# This is the algorithm that we learned in the lectures. I will not go over this algorithm, but to say that it is one of the most commonly used of the PRNG algorithms ("Random Number Generation", Wikipedia 2020).
# <br>
# <br>
# ### Mersenne Twister
#
# <br>
# The most popular and widely used general purpose PRNGs is the Mersenne Twister. Its name derives from its period length, a Mersenne Prime. The most common version of this algorithm (MT19937) uses the Mersenne Prime: $2^{19937}-1$ ("Mersenne Twister", Wikipedia 2020). The algorithm is very complicated and will not be discussed further. Below is a visualization of the generation procedure.
#
# <br><br>
#
# <img src=https://upload.wikimedia.org/wikipedia/commons/thumb/b/b5/Mersenne_Twister_visualisation.svg/1920px-Mersenne_Twister_visualisation.svg.png width=1200 title= "Mersenne Twister Visualization">
# <center>Figure 5. Mersenne Twister Visualization showing the generation of 32-bit pseudo-random numbers.</center>
# <br><br>
#
# Source: [Mersenne_Twister_visualisation.svg](https://upload.wikimedia.org/wikipedia/commons/thumb/b/b5/Mersenne_Twister_visualisation.svg/1920px-Mersenne_Twister_visualisation.svg.png),  Wikipedia.com.
#
# The [Wikipedia page](https://en.wikipedia.org/wiki/Mersenne_Twister) contains the psuedocode for implementing the algorithm.

# %% [markdown]
# ## 3.3 Middle Square Weyl Sequence
# ### From terrible to amazing!
#
# Von Neumann's Middle Square algorithm didn't have much going for it other than historical significance. That all changed in 2018 when Bernard Widynski modified the algorithm and created the Middle Square Weyl Sequence RNG (Widynski 2020). <b><u><i>This is possibly the fastest PRNG that passes all the standard statistical benchmark tests</i></u></b> ("Middle Square Method", Wikipedia 2020). The code for the algorithm is amazingly concise. Below is the C implementation for the algorithm:
#
# <code>
#
#     #include <stdint.h>
#
#     uint64_t x = 0, w = 0
#
#     // Must be odd (least significant bit is "1"), and upper 64-bits non-zero
#     uint64_t s = 0xb5ad4eceda1ce2a9; // qualifying seed
#
#     // return 32-bit number
#     inline static uint32_t msws() {
#         x *= x; // square the number
#         w += s; // the weyl sequence
#         x += w; // apply to x
#         return x = (x>>32) | (x<<32); // return the middle 32-bits
#     }
# </code>
#
# Source: [Aaron Toponce, Middle Square Weyl Sequence PRNG](https://pthree.org/2018/07/30/middle-square-weyl-sequence-prng/)
# <br><br>
#
# This code will generate a long period of well distributed random numbers.
# <br><br>
# Though the code is simple, the inner workings of the sequence to the algorithm are a bit more complicated.
#
# The following explanation of the algorithm is taken from [Aaron Toponce, Middle Square Weyl Sequence PRNG](https://pthree.org/2018/07/30/middle-square-weyl-sequence-prng/)
# <br><br>
#
# ***
# Suppose "x = 0xace983fe671dbd09". Then "x" is a 64-bit number with the following bits:
# >
# > 1010110011101001100000111111111001100111000111011011110100001001
# ***
# When that number is squared, it becomes the 128-bit number 0x74ca9e5f63b6047f6a65456d9da04a51, or in binary:
# > 01110100110010101001111001011111011000111011011000000100011111110110101001100101010001010110110110011101101000000100101001010001
# ***
# But remember, "x" is a 64-bit number, so in our C code, only the bottom 64-bits are returned from that 128-bit number.
#
# So "x" is really 0x6a65456d9da04a51, or in binary:
# > 0110101001100101010001010110110110011101101000000100101001010001
# ***
# But the bits "01101010011001010100010101101101" are the 3rd 32-bits of the 128-bit number that was the result of squaring "x" (see above). They are the "middle" 32-bits that we're after. So, we're going to do something rather clever. We're going to swap the upper 32-bits with the lower, then return the lower 32-bits.
#
# Effectively, what we're doing is "ABCD" -> "CDAB", then returning "AB". We do this via bit-shifting.
# ***
# So, starting with:
#
# > 0110101001100101010001010110110110011101101000000100101001010001
# ***
# First, we bitshift the 64-bit number right 32-bits:
#
# > 0110101001100101010001010110110110011101101000000100101001010001 >> 32
# > = 0000000000000000000000000000000001101010011001010100010101101101
# ***
# Then we bitshift "x" left 32-bits:
#
# > 0110101001100101010001010110110110011101101000000100101001010001 << 32
# > = 1001110110100000010010100101000100000000000000000000000000000000
# ***
# Now we logically "or" them together:
#
# > 0000000000000000000000000000000001101010011001010100010101101101 |
# > 1001110110100000010010100101000100000000000000000000000000000000
# ***
#  1001110110100000010010100101000101101010011001010100010101101101
# ***
#
# <br><br>
# Our Original Seed was: 12459634972772121865 (0xace983fe671dbd09 in hexadecimal)
#
# Our New Number is now: 11358159973766219117 (0x9da04a516a65456d in hexadecimal)
#
# <br><br>
# In May 2020, Widynski published a [paper](https://arxiv.org/pdf/1704.00358.pdf) with a further improvement of the algorithm, the Squares CBRNG, which is a Counters Based Random Number Generator.
#
# <br><br>
# The implementation of both the Middle Squares Weyl Sequence RNG and the Squares CBRNG are free from the creator and can be downloaded from this [location](https://mswsrng.wixsite.com/rand).
#
#
# <br><br>
#
# Below, I have created a Python implementation of the Middle Squares Weyl Sequence. Its performance is not spectacular, especially when compared to the Numpy Random Library functions, which use a C language backend to perform the computations.

# %% [markdown]
# ## 3.4 Python Implementation of Middle Square Weyl Sequence

# %%
# %matplotlib inline

import ctypes
# import base64
import matplotlib.pyplot as plt
import numpy as np
from time import time
from timeit import timeit
from numba import jit
# Plot text color, uncomment 'black' for a light background
COLOR = 'white'
#COLOR = 'black'

plt.rcParams['axes.facecolor']= '#373e4b'
plt.rcParams['axes.labelcolor'] = COLOR
# plt.rcParams['axes.prop_cycle'] = cycler(color='bgrcmyk')
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR

# %%
"""
    These are 100 of the 25,000 Weyl Sequence Integers provided in the
    MSWSRNG C implementation

"""

seeds = [0x8b5ad4cef9c2703b,0xdbc8915fabd37257,0x3a16e0c5540e9daf,0xbf3ac427d39cb715,0x1794da5278fd2947,
0x8fc49b2ab8d19c4f,0xde07a518b7cdae83,0xefbca361ea624309,0xb1d2e4762e7ab9c3,0x1ce27860c1b98d25,0x478f6219ef29ad87,
0x41857dc3e7f63db9,0xb9425ed81e87fb2d,0x3124b5df2d80b7fd,0xc3e587fb612ad579,0x9235eb64c2bf903f,0x91f0e7b8d41abce5,
0xc3867d19216ba45f,0xc1b48273d0f2c781,0xbd378fa2946ed8f5,0x4f0581ab2daf5e13,0xdab4e53c14f9c36f,0xf23ba0c5a042b18f,
0x3db58a0f70c53619,0xf67891357d842ce7,0x912a0b4cb2d148a3,0xce5326fa769182f3,0x5c7280d99f6a35c5,0x2e0941a8286dc4ab,
0xbc432d9a4a81e9c3,0x6dc431ba4b3875cd,0xe843c0564859b3a3,0xdb3409e79bd306a9,0x92a73b40703c41d7,0x17b082afe0da4619,
0x60952db40695ce43,0x1c364e9a41b39067,0x78cf5a932ba6e40d,0x62a8fc7b5a319b73,0x46ca273b21f8a4e3,0xf9b8ad6170b6a93f,
0x04de98fa8ac7e207,0x8950eacb4a36f8c5,0x490ceb3dd23e4f95,0xf042dcabd8923ec5,0x8239acef358e9cb3,0xb3801a4f9c5ed473,
0x52690af854c09787,0x5fe9742b6f3d4ca1,0xd0187596508e12df,0x4d6ea2871063ea7f,0x4819b5da10df8743,0x1f6bad23e1b93c61,
0xa12e0dcf5d7f0125,0x0d4e9375873bc621,0xa765f49dda8612e5,0x48fc72a9d9e08ba7,0xa54c91dbab83524d,0x08c3564a7be1da39,
0xd910e37ffecd1763,0x6ea95cb2b8041e95,0xd032a8b995a0d3e1,0xe3296d171ec4a36f,0x3d47ce08518c76eb,0x2d81fc60283a0dc7,
0x89b06c1a406951cb,0x5387014d9813a465,0x09e7816d21c78f9b,0x1bd74536293a8cb1,0x9e0d648fd43a56bd,0x2cd40e8a1a2d54bf,
0xad65f098e2af40bd,0xb63ae0243fe275a1,0xa890df71e5438b07,0x9c25f36712a6fc35,0xbcd4978e96ead40d,0x1c9f4e7d19a8d635,
0x6d47af058fd5a6cf,0xae21c38707e94d13,0x1b534c7ea1ed7b03,0x8ce526ba7da3b609,0x71ce6f0221bd57e5,0xc971b4e8cf56d471,
0xc962dfb8fb042a1d,0x952ebf073249c571,0xd7a50f43ce3d87a1,0xbda2195fad345f29,0x174a8cf54b98fd63,0xd138c9ef748b1e93,
0x6b479f8548a376e1,0x8215a6be079b8dcb,0x48b9c53638d90b25,0x951728dcba4f6d13,0xdc96fa472ab1c365,0x986d5cb3a90c6319,
0x302ad6bfbd6203ff,0xa350e8bfea914d6f,0x537d1bc2425e369b,0x03482bf5c4feb605,0x308f4cb7c9f85a4f]

# %%
def msws(seed=0xb5ad4eceda1ce2a9, 
         r_values=1, 
         scale=(2**32), 
         shifted=0):
    
    """
        Implementation of the Middle Squares Weyl Sequence
    """
    
    # C type casting to allow for bit shifting
    x = ctypes.c_uint64(0)
    w = ctypes.c_uint64(0)
    
    # list to hold the generated random numbers
    values = []

    # loop for generating the random number list
    for i in range(r_values):    
        
        # squaring the x value
        x.value *= x.value
        # adding the seed to the weyl sequence value
        w.value += seed
        # adding the new weyl sequence value to the square
        x.value += w.value
        
        # bit shifting to extract the "middle" value
        x.value = (x.value >> 32) | (x.value << 32)

        # convertingthe value to a 32-bit, this will extract the "middle" square
        x32 = ctypes.c_uint32(x.value).value

        # casting the number to align with the scale value
        if scale==1:
            x32 = int(x32/scale + shifted)
        elif scale==2**32:
            x32 = x32/scale + shifted
        else:
            tp = type(scale)
            x32 = tp(x32/scale + shifted) 
        
        # append the value to the list
        values.append(x32)
    
    return values

# %%
x_range = 1000

# s = 0xb5ad4eceda1ce2a9
s = seeds[int((10**7)*time()%(len(seeds)))]
# s = 212154654132134512

scale = 1
# scale = 2**32

timer_start = time()

int_values = msws(seed=s , r_values=x_range, scale=scale)

timer_end = time()
timer = timer_end - timer_start

print(f"Elapsed Time: {timer} seconds")
_x = np.linspace(0, x_range, x_range)
plt.scatter(_x, int_values)
plt.title(f"Scatter Plot of Random 32-bit Integers")
plt.show()

plt.hist(int_values, bins=11)
plt.title(f"Histogram of Distribution of Random 32-bit Integers")
plt.show()

print(min(int_values), max(int_values))
# Out:
# Elapsed Time: 0.002000570297241211 seconds
# 5875740 4290212606

# %%
x_range = 1000
# s = 0xb5ad4eceda1ce2a9
s = seeds[int((10**7)*time()%(len(seeds)))]
# s = 212154654132134512

# scale = 1
scale = 2**32

timer_start = time()

dec_values = msws(seed=s , r_values=x_range, scale=scale)

timer_end = time()
timer = timer_end - timer_start

print(f"Elapsed Time: {timer} seconds")
_x = np.linspace(0, x_range, x_range)
plt.scatter(_x, dec_values)
plt.title(f"Scatter Plot of Random 32-bit Decimal Values")
plt.show()

plt.hist(dec_values, bins=11)
plt.title(f"Histogram of Distribution of Random 32-bit Decimal values")
plt.show()

print(min(dec_values), max(dec_values))
# Out:
# Elapsed Time: 0.0010237693786621094 seconds
# 0.0007043303921818733 0.9977769355755299

# %%
"""
    Numpy random implimentation.
    For calculating individual random values, numpy is not impressively fast 

"""
small_sample = 10
large_sample = x_range

timer2_start = time()
# rndint = []

rndint_small = np.random.randint(low=0, high=2**31, size=small_sample)

# for i in range(x_range):
#     rndint.append(np.random.randint(low=0, high=2**31))
timer2_end = time()
timer2 = timer2_end - timer2_start
print(f"Elapsed Time for 1 value: {timer2} seconds")

timer3_start = time()
# rndint = []

rndint = np.random.randint(low=0, high=2**31, size=large_sample)

# for i in range(x_range):
#     rndint.append(np.random.randint(low=0, high=2**31))
timer3_end = time()
timer3 = timer3_end - timer3_start
print(f"Elapsed Time for {x_range} values: {timer3} seconds")
# print(f"Ratio of {x_range}:1 : {(timer3*1000)/(timer2*1000)} ")
_x = np.linspace(0, large_sample, large_sample)

plt.scatter(_x, rndint)
plt.title(f"Scatter Plot of Random 32-bit Decimal Values")
plt.show()

plt.hist(rndint, bins=11)
plt.title(f"Histogram of Distribution of Random 32-bit Decimal values")
plt.show()
print(min(rndint), max(rndint))
# print(len(rndint))
# Out:
# Elapsed Time for 1 value: 0.0 seconds
# Elapsed Time for 1000 values: 0.0 seconds
# 1897735 2144483122

# %% [markdown]
# ## 3.5 Next Steps
#
# I would really like to see the Middle Square Weyl Sequence Method properly implemented in Python. It would probably need to remain a C-language backend, with Python access front end.
#
# <br>
# For myself, I would like to attempt to port the code over to the Julia language, and see how it performs there. I don't think it would be difficult, but it definitely present some challenges, in partictular the bit shifting portion of the algorithm.

# %% [markdown]
# ## 4.1 Conclusion
# ### Applications
#
# What are random numbers good for? Where are they used? The answer is everywhere. They are integral to for the continued safety of the internet and financial transactions. Cryptography often uses a combination of the phyysical generators, such as the Intel DRNG, coupled with a PRNG to create the hash codes for encrypting data. Physical RNG's are essential for the Gaming industry to ensure true random results foir games of chance. Random number generators are essential in the video-game industry for game play creation and variety.
#
# In the science, PRNG's are essential for research purposes. They are required for Monte Carlo simulations, statistical sampling, AI, machine learning.
#
# ### Final Thoughts
# Creating these Random numbers computers presents a unique challenge. Computers are by natural designed to be logical and orderly. Randomness seems absolutely antithetical to the purpose and desgn of these machines. But as technology progresses, as our understnading of the worl around us and the Universe beyond advances, we find ourselves in need of introducing some disorder to facilate our further ordering of nature. The field of study, of random number generation, appears to vibrant and still advanceing. It is remarkable that a little used or regarded algorithm, of note only because it was the first of it's kind, can be improved upon to back to the cutting edge of technology, to fore front of the field. I beleive we still just at the beginning and them is still much to learn and room to grow in the field of random numbers.
#
# I know from a personal stand-point this is a fascinating subject. Decades ago a learned of the LavaRand lava lamp wall and its use in RNG for crypotgraphy. I thought it was so innovative, truly thinking outside the box. I still have much to learn, and I am excited to continue to grow and andvance my knowledge and skill in this field.

# %% [markdown]
# ## References
#
# Intel® Digital Random Number Generator (DRNG) Software Implementation Guide. (2018, October 17). Retrieved 20:16, December 6, 2020, from https://software.intel.com/content/www/us/en/develop/articles/intel-digital-random-number-generator-drng-software-implementation-guide.html.
# <br><br>
# L'Ecuyer, P., Diro, Gerad, and Cirrelt (2017). Pavillon Aisenstadt, Universite de Montreal ´
# Montreal (Quebec), CANADA. History of Uniform Random Number Generation. (PDF). Online Source. Proceedings of the 2017 Winter Simulation Conference. 202-230. Retrieved 20:16, December 6, 2020, from https://www.informs-sim.org/wsc17papers/includes/files/016.pdf.
# <br><br>
# Sidhpurwala, Huzaifa. "Understanding random number generators, and their limitations, in Linux" (2019, June 5). Retrieved 20:16, December 6, 2020, from https://www.redhat.com/en/blog/understanding-random-number-generators-and-their-limitations-linux.
# <br><br>
# Squares RNG (Website) Retrieved 20:16, December 6, 2020, from https://squaresrng.wixsite.com/rand
# <br><br>
# Toponce, Aaron. (2018, June 30). Middle Square Weyl Sequence PRNG. Retrieved 20:16, December 6, 2020, from https://pthree.org/2018/07/30/middle-square-weyl-sequence-prng/.
# <br><br>
# von Neumann, John (1951). Various techniques used in connection with random digits.(PDF). Online Source. National Bureau of Standards Applied Mathematics Series. 12: 36–38. Retrieved 20:16, December 6, 2020, from https://mcnp.lanl.gov/pdf_files/nbs_vonneumann.pdf
# <br><br>
# Widynski, Bernard. (2020, May 20). Middle Square Weyl Sequence RNG. Retrieved 20:16, December 6, 2020, from https://arxiv.org/pdf/1704.00358.pdf.
# <br><br>
# Wikipedia contributors. (2020, November 25). Mersenne Twister. In Wikipedia, The Free Encyclopedia. Retrieved 00:22, December 7, 2020, from https://en.wikipedia.org/w/index.php?title=Mersenne_Twister&oldid=990691870
# <br><br>
# Wikipedia contributors. (2020, November 24). Middle-square method. In Wikipedia, The Free Encyclopedia. Retrieved 20:16, December 6, 2020, from https://en.wikipedia.org/w/index.php?title=Middle-square_method&oldid=990420109.
# <br><br>
# Wikipedia contributors. (2020, November 30). Random number generation. In Wikipedia, The Free Encyclopedia. Retrieved 20:16, December 6, 2020, from https://en.wikipedia.org/w/index.php?title=Random_number_generation&oldid=991606463.
# <br><br>
# Wikipedia contributors. (2020, September 12). Weyl sequence. In Wikipedia, The Free Encyclopedia. Retrieved 00:22, December 7, 2020, from https://en.wikipedia.org/w/index.php?title=Weyl_sequence&oldid=978093654
# <br><br>
# Willerton, Rod "The Importance of Being E. R. N. I. E.". YouTube.com. (2014, November 22). Retrieved 20:16, December 6, 2020, from https://www.youtube.com/watch?v=rOAfbb5D3Dw.
# <br><br>
